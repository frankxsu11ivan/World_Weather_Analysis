# %%
# Import the random module.
#import random

# %%
#random.randint(-90,90)
# Out:
# 35

# %%
# 6.1.4Practice Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Space

# %%
#You can only unzip a zipped tuple once befoved from the computer's memory. 
#Make sure you unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
#space the next section is 6.1.5

# %%
#x = 1
#latitudes = []
#while x < 11:
    #random_lat = random.randint(-90, 89) + random.random()
    #latitudes.append(random_lat)
    #x += 1
#latitudes

# %%
#x = 1
#longitude = []
#while x < 11:
    #random_lngs = random.randint(-180, 179) + random.random()
    #longitude.append(random_lngs)
    #x += 1
#longitude

# %%
#random.randrange(-90, 90, step=3)

# %%
#random.uniform(-90, 90)

# %%
# 6.1.4Import the NumPy module.NumPy module is a numerical mathematics library
#The NumPy module has a built-in random module, and supplements the built-in Python random module. There is no need to import the random module if we import the NumPy module, as it's redundant.
import numpy as np

# %%
#np.random.uniform(-90.000, 90.000)

# %%
#prefered
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([ 53.76842606,  63.27880782, -58.49716614, -29.70656794,
#        -40.49218791,  82.18407527, -21.04229014, -19.72118932,
#        -50.70826672,  77.1140215 , -88.46594293, -50.88268627,
#         65.06846623,  67.45359633,  20.95079031,  34.29659911,
#        -73.84095701, -80.58684535,  21.18009607,  61.15184617,
#        -30.64096529,  35.96328766,  19.31261409,  66.83074327,
#         57.1124276 ,  38.40530081,  21.2683578 , -42.64890954,
#        -53.15029354,  73.94557418, -33.4415254 ,  -4.22993596,
#        -21.05859257, -30.64189247, -66.42153454,  -5.10945231,
#        -82.37468407,  52.06455383,  32.50699232, -77.75479261,
#        -10.67066898,   6.87086785,  -6.39898694,  48.5474914 ,
#        -77.10870086,  44.93488316, -45.8272477 , -83.88818938,
#        -12.35399442, -68.65168572])

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 12.9 µs ± 307 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.65 ms ± 63.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# 6.1.4Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
city = citipy.nearest_city(22.00, 120.21)
city

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# kodiak us
# hobart au
# butaritari ki
# torbay ca
# east london za
# kodiak us
# chulman ru
# thompson ca
# kimbe pg
# port alfred za
# gayny ru
# domoni km
# rikitea pf
# airai pw
# mareeba au
# nizhneyansk ru
# grand river south east mu
# kruisfontein za
# kavieng pg
# guerrero negro mx
# busselton au
# pangnirtung ca
# butaritari ki
# labrea br
# byron bay au
# college us
# ushuaia ar
# upernavik gl
# gonbad-e qabus ir
# bluff nz
# salta ar
# samarai pg
# severo-kurilsk ru
# udachnyy ru
# new norfolk au
# asyut eg
# upernavik gl
# jamestown sh
# chilca pe
# saleaula ws
# flinders au
# chuy uy
# cape town za
# punta arenas cl
# torbay ca
# fort saint john ca
# busselton au
# busselton au
# new norfolk au
# faya td
# albany au
# saint-philippe re
# bayji iq
# abu samrah qa
# ancud cl
# ushuaia ar
# carnarvon au
# tromso no
# grindavik is
# ameca mx
# yellowknife ca
# apaxtla mx
# punta arenas cl
# grindavik is
# abu samrah qa
# abu dhabi ae
# college us
# constitucion mx
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 598
